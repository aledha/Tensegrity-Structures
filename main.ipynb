# %%
# %reload_ext autoreload 
# %autoreload
import numpy as np
np.random.seed(1)
np.set_printoptions(suppress=True, precision=6)

# %% [markdown]
# ## Cable system where solution is known

# %%
# %autoreload
import examples as ex
ex.cable_sys()
# Out:
# Converged after 26 iterations
# System after optimizing:  [[ 5.   5.   0. ]
#  [-5.   5.   0. ]
#  [-5.  -5.   0. ]
#  [ 5.  -5.   0. ]
#  [ 2.   2.  -1.5]
#  [-2.   2.  -1.5]
#  [-2.  -2.  -1.5]
#  [ 2.  -2.  -1.5]]
# 2 norm of the difference between numerical and exact solution 1.5533939047485077e-07

# %% [markdown]
# ## Test case with cables and bars

# %%
# %autoreload
ex.cables_and_bars()
# Out:
# Converged after 83 iterations
# [[ 1.        1.        0.      ]
#  [-1.        1.        0.      ]
#  [-1.       -1.        0.      ]
#  [ 1.       -1.        0.      ]
#  [-0.7095   -0.000001  9.54    ]
#  [ 0.000004 -0.7095    9.54    ]
#  [ 0.7095   -0.000001  9.54    ]
#  [ 0.000004  0.7095    9.54    ]]
# 2 norm of the difference between numerical and exact solution 2.2176227747552922e-05

# %% [markdown]
# ### Tensegrity table

# %%
# %autoreload
ex.tensegrity_table()
# Out:
# Converged after 23 iterations

# %% [markdown]
# ## With ground, quadratic constraints

# %%
# %autoreload
ex.with_ground_quad_constraints()
# Out:
# [[-0.000001  0.000008 -0.000001]
#  [-2.007416  0.000121 -0.000001]
#  [-2.007516 -2.007294 -0.000001]
#  [-0.000101 -2.007407 -0.000001]
#  [-1.713539 -1.004244  9.54136 ]
#  [-1.003153 -1.713304  9.541375]
#  [-0.294095 -1.002917  9.54137 ]
#  [-1.004481 -0.293857  9.541346]]

# %%
# %autoreload
ex.free_standing_bridge()
# Out:
# Converged after 329 iterations
