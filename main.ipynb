# %%
# %reload_ext autoreload 
# %autoreload
import numpy as np
np.random.seed(1)
np.set_printoptions(suppress=True, precision=6)

# %% [markdown]
# ## Cable system where solution is known

# %%
# %autoreload
import examples as ex
ex.cable_sys()
# Out:
# Converged after 35 iterations
# System after optimizing:  [[ 5.   5.   0. ]
#  [-5.   5.   0. ]
#  [-5.  -5.   0. ]
#  [ 5.  -5.   0. ]
#  [ 2.   2.  -1.5]
#  [-2.   2.  -1.5]
#  [-2.  -2.  -1.5]
#  [ 2.  -2.  -1.5]]
# 2 norm of the difference between numerical and exact solution 3.113313773438017e-12

# %% [markdown]
# ## Test case with cables and bars

# %%
# %autoreload
ex.cables_and_bars()
# Out:
# Converged after 89 iterations
# [[ 1.      1.      0.    ]
#  [-1.      1.      0.    ]
#  [-1.     -1.      0.    ]
#  [ 1.     -1.      0.    ]
#  [-0.7095 -0.      9.54  ]
#  [ 0.     -0.7095  9.54  ]
#  [ 0.7095 -0.      9.54  ]
#  [ 0.      0.7095  9.54  ]]
# 2 norm of the difference between numerical and exact solution 2.0692633316276288e-05

# %% [markdown]
# ### Tensegrity table

# %%
# %autoreload
ex.tensegrity_table()
# Out:
# Converged after 24 iterations

# %% [markdown]
# ## With ground, quadratic constraints

# %%
# %autoreload
ex.with_ground_quad_constraints()
# Out:
# Converged after 104 iterations
# [[ 0.        0.       -0.000001]
#  [-2.007415  0.000149 -0.000001]
#  [-2.007565 -2.007266 -0.000001]
#  [-0.000149 -2.007415 -0.000001]
#  [-1.713505 -1.004281  9.541363]
#  [-1.003135 -1.713356  9.541363]
#  [-0.29406  -1.002986  9.541363]
#  [-1.00443  -0.29391   9.541363]]

# %%
# %autoreload
ex.free_standing_bridge()
# Out:
# Converged after 340 iterations
