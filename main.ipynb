# %%
# %reload_ext autoreload 
# %autoreload
import numpy as np
np.random.seed(1)
np.set_printoptions(suppress=True, precision=6)

# %% [markdown]
# ## Cable system where solution is known

# %%
# %autoreload
import examples as ex
ex.cable_sys()
# Out:
# Converged after 40 iterations
# System after optimizing:  [[ 5.   5.   0. ]
#  [-5.   5.   0. ]
#  [-5.  -5.   0. ]
#  [ 5.  -5.   0. ]
#  [ 2.   2.  -1.5]
#  [-2.   2.  -1.5]
#  [-2.  -2.  -1.5]
#  [ 2.  -2.  -1.5]]
# 2 norm of the difference between numerical and exact solution: 9.155133597044475e-16
# 2 norm of the gradient in the last iteration: 0.0

# %% [markdown]
# ## Test case with cables and bars

# %%
# %autoreload
ex.cables_and_bars()
# Out:
# Converged after 82 iterations
# [[ 1.      1.      0.    ]
#  [-1.      1.      0.    ]
#  [-1.     -1.      0.    ]
#  [ 1.     -1.      0.    ]
#  [-0.7095  0.      9.54  ]
#  [-0.     -0.7095  9.54  ]
#  [ 0.7095 -0.      9.54  ]
#  [-0.      0.7095  9.54  ]]
# 2 norm of the difference between numerical and exact solution 2.0692592174390447e-05
# 2 norm of the gradient in the last iteration: 8.7818686072051e-17

# %% [markdown]
# ### Tensegrity table

# %%
# %autoreload
ex.tensegrity_table()
# Out:
# Converged after 25 iterations
# 2 norm of the gradient in the last iteration: 5.255465616227392e-15

# %% [markdown]
# ## With ground, quadratic constraints

# %%
# %autoreload
ex.with_ground_quad_constraints()
# Out:
# Converged after 109 iterations
# [[-0.        0.       -0.000001]
#  [-2.007415  0.000149 -0.000001]
#  [-2.007565 -2.007266 -0.000001]
#  [-0.000149 -2.007415 -0.000001]
#  [-1.713505 -1.004281  9.541363]
#  [-1.003135 -1.713356  9.541363]
#  [-0.29406  -1.002986  9.541363]
#  [-1.00443  -0.29391   9.541363]]
# 2 norm of the gradient in the last iteration: 7.217557701420128e-17

# %%
# %autoreload
ex.free_standing_bridge()
# Higher tolerance since it takes so long to run
# Out:
# Converged after 340 iterations
# 2 norm of the gradient in the last iteration: 8.474545310099999e-07
