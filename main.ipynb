# %%
# %reload_ext autoreload 
# %autoreload
import numpy as np
np.random.seed(1)
np.set_printoptions(suppress=True, precision=6)

# %% [markdown]
# ## Cable system where solution is known

# %%
# %reload_ext autoreload 
# %autoreload
import examples as ex
ex.cable_sys()
# Out:
# Converged after 26 iterations
# [[ 2.   2.  -1.5]
#  [-2.   2.  -1.5]
#  [-2.  -2.  -1.5]
#  [ 2.  -2.  -1.5]]

# %% [markdown]
# ## Test case with cables and bars

# %%
ex.cables_and_bars()
# Out:
# Converged after 63 iterations
# [[-0.709     0.        9.195   ]
#  [-0.000006 -0.709     9.195   ]
#  [ 0.709    -0.000001  9.195   ]
#  [-0.000005  0.709     9.195   ]]

# %% [markdown]
# ### Tensegrity table

# %%
ex.tensegrity_table()
# Out:
# Converged after 26 iterations

# %% [markdown]
# ## With ground, quadratic constraints

# %%
# %autoreload
ex.with_ground_quad_constraints()
# Out:
# Converged after 93 iterations
# [[ 1.        1.       -0.      ]
#  [-1.007657  1.00157  -0.      ]
#  [-1.009227 -1.006087 -0.      ]
#  [ 0.99843  -1.007657 -0.      ]
#  [-0.714342 -0.009582  9.5366  ]
#  [ 0.001925 -0.712772  9.5366  ]
#  [ 0.705115  0.003495  9.5366  ]
#  [-0.011152  0.706685  9.5366  ]]

# %%
# %autoreload
ex.free_standing_bridge()
