# %%
# %reload_ext autoreload 
# %autoreload
import numpy as np
np.random.seed(1)
np.set_printoptions(suppress=True, precision=6)

# %% [markdown]
# ## Cable system where solution is known

# %%
# %autoreload
import examples as ex
ex.cable_sys()
# Out:
# Converged after 27 iterations
# [[ 5.   5.   0. ]
#  [-5.   5.   0. ]
#  [-5.  -5.   0. ]
#  [ 5.  -5.   0. ]
#  [ 2.   2.  -1.5]
#  [-2.   2.  -1.5]
#  [-2.  -2.  -1.5]
#  [ 2.  -2.  -1.5]]

# %% [markdown]
# ## Test case with cables and bars

# %%
ex.cables_and_bars()
# Out:
# Converged after 65 iterations
# [[ 1.        1.        0.      ]
#  [-1.        1.        0.      ]
#  [-1.       -1.        0.      ]
#  [ 1.       -1.        0.      ]
#  [-0.709     0.000001  9.195   ]
#  [-0.000005 -0.709     9.195   ]
#  [ 0.709     0.000001  9.195   ]
#  [-0.000005  0.709     9.195   ]]

# %% [markdown]
# ### Tensegrity table

# %%
# %autoreload
ex.tensegrity_table()
# Out:
# Converged after 26 iterations

# %% [markdown]
# ## With ground, quadratic constraints

# %%
# %autoreload
ex.with_ground_quad_constraints()
# Out:
# Converged after 22 iterations
# [[ 0.021509 -0.010767 -0.000981]
#  [-1.989234  0.021509 -0.000981]
#  [-2.021509 -1.989233 -0.000981]
#  [-0.010767 -2.021509 -0.000981]
#  [-1.709028 -1.045122  9.759068]
#  [-0.954878 -1.709028  9.759068]
#  [-0.290972 -0.954878  9.759068]
#  [-1.045122 -0.290972  9.759068]]

# %%
ex.free_standing_bridge()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-a7588784aacf> in <module>
# ----> 1 ex.free_standing_bridge()
#
# ~/Documents/TMA4180 Optimization/Tensegrity-Structures/examples.py in free_standing_bridge(g, rho, c, k, mu, N, tower_height, tower_distances, bridge_stretch, max_iter)
#     255
#     256     X0 = X0.flatten()
# --> 257     X1, gradients = solver.BFGS(X0, N, 0, max_iter, f, df)
#     258     cplot.plot_points(X0, X1, cables, bars, 0, gradients, title = 'Free standing bridge', plot_view = 'x', zprojection = False)
#
# ~/Documents/TMA4180 Optimization/Tensegrity-Structures/solver.py in BFGS(X0, N, M, maxiter, f, df, tol)
#      84         p = -H @ grad
#      85
# ---> 86         alpha = line_search(Y1, p, c1, c2, f, df)
#      87         Y0 = Y1
#      88         Y1 = Y0 + alpha * p
#
# ~/Documents/TMA4180 Optimization/Tensegrity-Structures/solver.py in line_search(x, p, c1, c2, f, df, maxiter)
#      37             else:
#      38                 alpha *= 2
# ---> 39         I = f(x + alpha * p) <= f(x) + c1 * alpha * np.inner(df(x), p)
#      40         II = np.abs(np.inner(df(x + alpha * p), p)) <= c2 * np.abs(np.inner(df(x), p))
#      41         iter += 1
#
# ~/Documents/TMA4180 Optimization/Tensegrity-Structures/examples.py in f(X)
#     249
#     250     def f(X):
# --> 251         return efunc.Q(X, mu_1, mu_2, cables, bars, ms, consts)
#     252
#     253     def df(X):
#
# ~/Documents/TMA4180 Optimization/Tensegrity-Structures/energy_functions.py in Q(X, mu_1, mu_2, cables, bars, ms, consts)
#     123         float: energy in system, in addition to penalty
#     124     """
# --> 125     return E(X, cables, bars, ms, consts) + 1/2 * mu_1 * np.sum(cmin(X[2::3])**2) + 1/2 * mu_2 * (X[0]**2 + X[1]**2)
#     126
#     127 def dQ(X, mu_1, mu_2, cables, bars, ms, consts, N):
#
# ~/Documents/TMA4180 Optimization/Tensegrity-Structures/energy_functions.py in E(X, cables, bars, ms, consts)
#      29     for i, j in bars_indices.T:
#      30         grav_bar += bars[i, j] * (X[i, 2] + X[j, 2])
# ---> 31         elast_bar += (np.linalg.norm(X[i] - X[j]) - bars[i, j])**2 / bars[i, j]**2
#      32     E_bar = rho * g * grav_bar / 2 + c / 2 *  elast_bar
#      33
#
# KeyboardInterrupt:
