# %%
# %reload_ext autoreload 
# %autoreload
import numpy as np
np.random.seed(1)
np.set_printoptions(suppress=True, precision=6)

# %% [markdown]
# ## Cable system where solution is known

# %%
# %reload_ext autoreload 
# %autoreload
import examples as ex
ex.cable_sys()
# Out:
# Converged after 26 iterations
# [[ 2.   2.  -1.5]
#  [-2.   2.  -1.5]
#  [-2.  -2.  -1.5]
#  [ 2.  -2.  -1.5]]

# %% [markdown]
# ## Test case with cables and bars

# %%
ex.cables_and_bars()
# Out:
# Converged after 63 iterations
# [[-0.709     0.        9.195   ]
#  [-0.000006 -0.709     9.195   ]
#  [ 0.709    -0.000001  9.195   ]
#  [-0.000005  0.709     9.195   ]]

# %% [markdown]
# ### Tensegrity table

# %%
ex.tensegrity_table()
# Out:
# Converged after 26 iterations

# %% [markdown]
# ## With ground, quadratic constraints

# %%
ex.with_ground_quad_constraints()
# Out:
# Converged after 59 iterations
# [[ 0.        0.       -0.000001]
#  [-0.955675  0.316334 -0.000001]
#  [-1.272009 -0.639341 -0.000001]
#  [-0.316334 -0.955675 -0.000001]
#  [-1.334294 -0.457808  9.192508]
#  [-0.497866 -1.01796   9.192508]
#  [ 0.062286 -0.181532  9.192508]
#  [-0.774142  0.378619  9.192508]]

# %%
ex.free_standing_bridge()
