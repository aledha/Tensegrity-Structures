# %%
# %reload_ext autoreload 
# %autoreload
import numpy as np
np.random.seed(1)
np.set_printoptions(suppress=True, precision=6)

# %% [markdown]
# ## Cable system where solution is known

# %%
# %autoreload
import examples as ex
ex.cable_sys()
# Out:
# Converged after 27 iterations
# [[ 5.   5.   0. ]
#  [-5.   5.   0. ]
#  [-5.  -5.   0. ]
#  [ 5.  -5.   0. ]
#  [ 2.   2.  -1.5]
#  [-2.   2.  -1.5]
#  [-2.  -2.  -1.5]
#  [ 2.  -2.  -1.5]]

# %% [markdown]
# ## Test case with cables and bars

# %%
ex.cables_and_bars()
# Out:
# Converged after 65 iterations
# [[ 1.        1.        0.      ]
#  [-1.        1.        0.      ]
#  [-1.       -1.        0.      ]
#  [ 1.       -1.        0.      ]
#  [-0.709     0.000001  9.195   ]
#  [-0.000005 -0.709     9.195   ]
#  [ 0.709     0.000001  9.195   ]
#  [-0.000005  0.709     9.195   ]]

# %% [markdown]
# ### Tensegrity table

# %%
# %autoreload
ex.tensegrity_table()
# Out:
# Converged after 26 iterations

# %% [markdown]
# ## With ground, quadratic constraints

# %%
# %autoreload
ex.with_ground_quad_constraints()
# Out:
# Converged after 80 iterations
# [[ 0.021473 -0.010733 -0.000098]
#  [-1.98927   0.021476 -0.000098]
#  [-2.021476 -1.989268 -0.000098]
#  [-0.010732 -2.021477 -0.000098]
#  [-1.709026 -1.045145  9.759952]
#  [-0.954853 -1.709026  9.759951]
#  [-0.290972 -0.954854  9.759951]
#  [-1.045145 -0.290973  9.759951]]

# %%
ex.free_standing_bridge()
