# %%
# %reload_ext autoreload 
# %autoreload
import numpy as np
np.random.seed(1)
np.set_printoptions(suppress=True, precision=6)

# %% [markdown]
# ## Cable system where solution is known

# %%
# %reload_ext autoreload 
# %autoreload
import examples as ex
ex.cable_sys()
# Out:
# Converged after 26 iterations
# [[ 2.   2.  -1.5]
#  [-2.   2.  -1.5]
#  [-2.  -2.  -1.5]
#  [ 2.  -2.  -1.5]]

# %% [markdown]
# ## Test case with cables and bars

# %%
ex.cables_and_bars()
# Out:
# Converged after 63 iterations
# [[-0.709     0.        9.195   ]
#  [-0.000006 -0.709     9.195   ]
#  [ 0.709    -0.000001  9.195   ]
#  [-0.000005  0.709     9.195   ]]

# %% [markdown]
# ### Tensegrity table

# %%
ex.tensegrity_table()
# Out:
# Converged after 26 iterations

# %% [markdown]
# ## With ground, quadratic constraints

# %%
# %autoreload
ex.with_ground_quad_constraints()
# Out:
# Converged after 974 iterations
# [[-0.        0.       -0.000001]
#  [ 1.529439  1.296974 -0.      ]
#  [-0.        0.       -0.      ]
#  [ 1.529439  1.296974 -0.000001]
#  [ 7.371915 -6.367819 -0.000001]
#  [ 6.607196 -7.016306 -0.000001]
#  [ 7.371915 -6.367819 -0.000001]
#  [ 6.607196 -7.016306 -0.      ]]

# %%
ex.free_standing_bridge()
