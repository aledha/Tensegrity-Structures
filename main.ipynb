# %%
# %reload_ext autoreload 
# %autoreload
import numpy as np
np.random.seed(1)
np.set_printoptions(suppress=True, precision=6)

# %% [markdown]
# ## Cable system where solution is known

# %%
# %autoreload
import examples as ex
ex.cable_sys()
# Out:
# Converged after 26 iterations
# 2-norm of difference between exact and numerical:  1.5533939047485077e-07
# [[ 5.   5.   0. ]
#  [-5.   5.   0. ]
#  [-5.  -5.   0. ]
#  [ 5.  -5.   0. ]
#  [ 2.   2.  -1.5]
#  [-2.   2.  -1.5]
#  [-2.  -2.  -1.5]
#  [ 2.  -2.  -1.5]]

# %% [markdown]
# ## Test case with cables and bars

# %%
# %autoreload
ex.cables_and_bars()
# Out:
# Converged after 83 iterations
# 2-norm of difference between exact and numerical:  2.2176227747552922e-05
# [[ 1.        1.        0.      ]
#  [-1.        1.        0.      ]
#  [-1.       -1.        0.      ]
#  [ 1.       -1.        0.      ]
#  [-0.7095   -0.000001  9.54    ]
#  [ 0.000004 -0.7095    9.54    ]
#  [ 0.7095   -0.000001  9.54    ]
#  [ 0.000004  0.7095    9.54    ]]

# %% [markdown]
# ### Tensegrity table

# %%
# %autoreload
ex.tensegrity_table()
# Out:
# Converged after 23 iterations

# %% [markdown]
# ## With ground, quadratic constraints

# %%
# %autoreload
ex.with_ground_quad_constraints()
# Out:
# Converged after 42 iterations
# [[ 0.021475 -0.010732 -0.000098]
#  [-1.989269  0.021475 -0.000098]
#  [-2.021475 -1.989268 -0.000098]
#  [-0.010732 -2.021475 -0.000098]
#  [-1.709027 -1.045146  9.759951]
#  [-0.954854 -1.709027  9.759951]
#  [-0.290973 -0.954854  9.759951]
#  [-1.045146 -0.290973  9.759951]]

# %%
ex.free_standing_bridge(max_iter = 1000, rho = 0, c = 200)
# Out:
# Converged after 329 iterations
